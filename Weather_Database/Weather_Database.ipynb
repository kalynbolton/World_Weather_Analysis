# %%
# DELIVERABLE 1
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 3. Create a new set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# 3. Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4. Import citipy module
from citipy import citipy

# %%
# 4. Create a list for holding the cities.
cities = []
# 4. Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# 4. Print the city count to confirm sufficient count.
len(cities)
# Out:
# 776

# %%
# 5. import the requests library
import requests

# 5. import the API key
from config import weather_api_key

# %%
# 5. Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 5. Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities - try-except block learning
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descript = city_weather["weather"][0]["main"]
        city_details = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description":city_details
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sorong
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | cidreira
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | terekli-mekteb
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | hirara
# Processing Record 12 of Set 1 | yemelyanovo
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | eureka
# Processing Record 18 of Set 1 | soyo
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | padang
# Processing Record 21 of Set 1 | gorin
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | sabang
# Processing Record 24 of Set 1 | nicolas de pierola
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | aykhal
# Processing Record 27 of Set 1 | zaragoza
# Processing Record 28 of Set 1 | tabora
# Processing Record 29 of Set 1 | itarema
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | merauke
# Processing Record 32 of Set 1 | mutum
# Processing Record 33 of Set 1 | broome
# Processing Record 34 of Set 1 | isangel
# Processing Record 35 of Set 1 | tazovskiy
# Processing Record 36 of Set 1 | betlitsa
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | mandalgovi
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | point pedro
# Processing Record 42 of Set 1 | touros
# Processing Record 43 of Set 1 | buraydah
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | bambous virieux
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | bandarbeyla
# Processing Record 50 of Set 1 | guerrero negro
# Processing Record 1 of Set 2 | chissamba
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | nyrob
# Processing Record 4 of Set 2 | la ligua
# Processing Record 5 of Set 2 | matagami
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | taltal
# Processing Record 8 of Set 2 | chakia
# Processing Record 9 of Set 2 | jamame
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | katsuura
# Processing Record 12 of Set 2 | constitucion
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | mareeba
# Processing Record 15 of Set 2 | desur
# Processing Record 16 of Set 2 | kalemie
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | torres
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | ludvika
# Processing Record 21 of Set 2 | walvis bay
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | cayenne
# Processing Record 24 of Set 2 | chuy
# Processing Record 25 of Set 2 | rio grande
# Processing Record 26 of Set 2 | chipata
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 2 | cabedelo
# Processing Record 30 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 2 | dangara
# Processing Record 32 of Set 2 | saraland
# Processing Record 33 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 2 | murgab
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | vardo
# Processing Record 37 of Set 2 | malur
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | kieta
# Processing Record 40 of Set 2 | conde
# Processing Record 41 of Set 2 | lancaster
# Processing Record 42 of Set 2 | narsaq
# Processing Record 43 of Set 2 | kiunga
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | fortuna
# Processing Record 47 of Set 2 | chagoda
# Processing Record 48 of Set 2 | moscow
# Processing Record 49 of Set 2 | grand forks
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | osny
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 3 | goundi
# Processing Record 5 of Set 3 | horadiz
# Processing Record 6 of Set 3 | hailey
# Processing Record 7 of Set 3 | chicama
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | mackay
# Processing Record 10 of Set 3 | sola
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | udachnyy
# Processing Record 13 of Set 3 | almaznyy
# Processing Record 14 of Set 3 | port-gentil
# Processing Record 15 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 3 | maceio
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | lompoc
# Processing Record 19 of Set 3 | alihe
# Processing Record 20 of Set 3 | tuktoyaktuk
# Processing Record 21 of Set 3 | meulaboh
# Processing Record 22 of Set 3 | hobart
# Processing Record 23 of Set 3 | nesoddtangen
# Processing Record 24 of Set 3 | lagoa
# Processing Record 25 of Set 3 | glens falls
# Processing Record 26 of Set 3 | kloulklubed
# Processing Record 27 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 3 | hit
# Processing Record 29 of Set 3 | sakakah
# Processing Record 30 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 3 | thompson
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | rocha
# Processing Record 34 of Set 3 | stonewall
# Processing Record 35 of Set 3 | sungaipenuh
# Processing Record 36 of Set 3 | coffs harbour
# Processing Record 37 of Set 3 | bosaso
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | sao filipe
# Processing Record 40 of Set 3 | hilton head island
# Processing Record 41 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 3 | sitka
# Processing Record 43 of Set 3 | shakawe
# Processing Record 44 of Set 3 | caravelas
# Processing Record 45 of Set 3 | muros
# Processing Record 46 of Set 3 | korla
# Processing Record 47 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 3 | saldanha
# Processing Record 49 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 3 | arkansas city
# Processing Record 1 of Set 4 | beyneu
# Processing Record 2 of Set 4 | acuna
# City not found. Skipping...
# Processing Record 3 of Set 4 | komsomolskiy
# Processing Record 4 of Set 4 | salalah
# Processing Record 5 of Set 4 | nara
# Processing Record 6 of Set 4 | lokosovo
# Processing Record 7 of Set 4 | faanui
# Processing Record 8 of Set 4 | leshukonskoye
# Processing Record 9 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 4 | pevek
# Processing Record 11 of Set 4 | olafsvik
# Processing Record 12 of Set 4 | altay
# Processing Record 13 of Set 4 | alice springs
# Processing Record 14 of Set 4 | pousat
# City not found. Skipping...
# Processing Record 15 of Set 4 | esterhazy
# Processing Record 16 of Set 4 | san clemente
# Processing Record 17 of Set 4 | zhanaozen
# Processing Record 18 of Set 4 | luderitz
# Processing Record 19 of Set 4 | umm lajj
# Processing Record 20 of Set 4 | ancud
# Processing Record 21 of Set 4 | tasiilaq
# Processing Record 22 of Set 4 | minab
# Processing Record 23 of Set 4 | raozan
# City not found. Skipping...
# Processing Record 24 of Set 4 | khazar
# Processing Record 25 of Set 4 | port lincoln
# Processing Record 26 of Set 4 | sao luis
# Processing Record 27 of Set 4 | bad wurzach
# Processing Record 28 of Set 4 | tunceli
# Processing Record 29 of Set 4 | torbay
# Processing Record 30 of Set 4 | athabasca
# Processing Record 31 of Set 4 | the valley
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | nalut
# Processing Record 34 of Set 4 | husavik
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | boone
# Processing Record 37 of Set 4 | bumba
# Processing Record 38 of Set 4 | khatanga
# Processing Record 39 of Set 4 | paamiut
# Processing Record 40 of Set 4 | capao da canoa
# Processing Record 41 of Set 4 | springfield
# Processing Record 42 of Set 4 | arnoldstein
# Processing Record 43 of Set 4 | palmer
# Processing Record 44 of Set 4 | monzon
# Processing Record 45 of Set 4 | novo aripuana
# Processing Record 46 of Set 4 | georgetown
# Processing Record 47 of Set 4 | eirunepe
# Processing Record 48 of Set 4 | ilulissat
# Processing Record 49 of Set 4 | sorland
# Processing Record 50 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 5 | necochea
# Processing Record 2 of Set 5 | muriwai beach
# Processing Record 3 of Set 5 | filingue
# Processing Record 4 of Set 5 | banda aceh
# Processing Record 5 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 6 of Set 5 | kavieng
# Processing Record 7 of Set 5 | sambava
# Processing Record 8 of Set 5 | qaanaaq
# Processing Record 9 of Set 5 | yarmouth
# Processing Record 10 of Set 5 | xai-xai
# Processing Record 11 of Set 5 | khandbari
# Processing Record 12 of Set 5 | luangwa
# Processing Record 13 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 5 | nome
# Processing Record 15 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 5 | zaysan
# Processing Record 17 of Set 5 | cabo san lucas
# Processing Record 18 of Set 5 | saskylakh
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | dawlatabad
# Processing Record 21 of Set 5 | khash
# Processing Record 22 of Set 5 | gao
# Processing Record 23 of Set 5 | kashi
# Processing Record 24 of Set 5 | los llanos de aridane
# Processing Record 25 of Set 5 | pleasant point
# Processing Record 26 of Set 5 | mitu
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | cervo
# Processing Record 29 of Set 5 | ketchikan
# Processing Record 30 of Set 5 | dicabisagan
# Processing Record 31 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 32 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 5 | wuan
# Processing Record 34 of Set 5 | chapais
# Processing Record 35 of Set 5 | nhulunbuy
# Processing Record 36 of Set 5 | haines junction
# Processing Record 37 of Set 5 | zhigansk
# Processing Record 38 of Set 5 | beisfjord
# Processing Record 39 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 5 | vitoria da conquista
# Processing Record 41 of Set 5 | fundacion
# Processing Record 42 of Set 5 | westport
# Processing Record 43 of Set 5 | fairbanks
# Processing Record 44 of Set 5 | fiumicino
# Processing Record 45 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 46 of Set 5 | longyearbyen
# Processing Record 47 of Set 5 | raga
# Processing Record 48 of Set 5 | ayagoz
# Processing Record 49 of Set 5 | norman wells
# Processing Record 50 of Set 5 | yeppoon
# Processing Record 1 of Set 6 | vagay
# Processing Record 2 of Set 6 | chokurdakh
# Processing Record 3 of Set 6 | christchurch
# Processing Record 4 of Set 6 | la baule-escoublac
# Processing Record 5 of Set 6 | moron
# Processing Record 6 of Set 6 | saint-philippe
# Processing Record 7 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 6 | saint-leu
# Processing Record 9 of Set 6 | nuuk
# Processing Record 10 of Set 6 | alhandra
# Processing Record 11 of Set 6 | nassjo
# Processing Record 12 of Set 6 | cerignola
# Processing Record 13 of Set 6 | borskoye
# Processing Record 14 of Set 6 | perpignan
# Processing Record 15 of Set 6 | kaeo
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | puerto escondido
# Processing Record 18 of Set 6 | byron bay
# Processing Record 19 of Set 6 | lebu
# Processing Record 20 of Set 6 | sampit
# Processing Record 21 of Set 6 | east london
# Processing Record 22 of Set 6 | lavrentiya
# Processing Record 23 of Set 6 | akhmeta
# Processing Record 24 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 6 | atbasar
# Processing Record 26 of Set 6 | bonavista
# Processing Record 27 of Set 6 | marsa matruh
# Processing Record 28 of Set 6 | marystown
# Processing Record 29 of Set 6 | alofi
# Processing Record 30 of Set 6 | dagua
# Processing Record 31 of Set 6 | svetlogorsk
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | chumikan
# Processing Record 34 of Set 6 | teya
# Processing Record 35 of Set 6 | tuatapere
# Processing Record 36 of Set 6 | barrow
# Processing Record 37 of Set 6 | tiksi
# Processing Record 38 of Set 6 | deputatskiy
# Processing Record 39 of Set 6 | cascais
# Processing Record 40 of Set 6 | micoud
# Processing Record 41 of Set 6 | iberia
# Processing Record 42 of Set 6 | verkhnyaya sinyachikha
# Processing Record 43 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 44 of Set 6 | muroto
# Processing Record 45 of Set 6 | hoa binh
# Processing Record 46 of Set 6 | kayerkan
# Processing Record 47 of Set 6 | thinadhoo
# Processing Record 48 of Set 6 | battle creek
# Processing Record 49 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 6 | khilok
# Processing Record 1 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 7 | wewak
# Processing Record 3 of Set 7 | guayaramerin
# Processing Record 4 of Set 7 | aleksandrov gay
# Processing Record 5 of Set 7 | cortes
# Processing Record 6 of Set 7 | lata
# Processing Record 7 of Set 7 | bayangol
# Processing Record 8 of Set 7 | pagangan
# Processing Record 9 of Set 7 | port blair
# Processing Record 10 of Set 7 | hegang
# Processing Record 11 of Set 7 | saint-francois
# Processing Record 12 of Set 7 | noumea
# Processing Record 13 of Set 7 | poya
# Processing Record 14 of Set 7 | jorhat
# Processing Record 15 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 7 | karratha
# Processing Record 17 of Set 7 | japura
# Processing Record 18 of Set 7 | massaguet
# Processing Record 19 of Set 7 | provideniya
# Processing Record 20 of Set 7 | ust-ishim
# Processing Record 21 of Set 7 | margate
# Processing Record 22 of Set 7 | chatrapur
# Processing Record 23 of Set 7 | santa cruz
# Processing Record 24 of Set 7 | bathsheba
# Processing Record 25 of Set 7 | lasa
# Processing Record 26 of Set 7 | mount gambier
# Processing Record 27 of Set 7 | predivinsk
# Processing Record 28 of Set 7 | arraial do cabo
# Processing Record 29 of Set 7 | nishihara
# Processing Record 30 of Set 7 | san cristobal
# Processing Record 31 of Set 7 | ahipara
# Processing Record 32 of Set 7 | mapimi
# Processing Record 33 of Set 7 | auki
# Processing Record 34 of Set 7 | jiblah
# Processing Record 35 of Set 7 | gilroy
# Processing Record 36 of Set 7 | omboue
# Processing Record 37 of Set 7 | mukhen
# Processing Record 38 of Set 7 | quelimane
# Processing Record 39 of Set 7 | manta
# Processing Record 40 of Set 7 | dingle
# Processing Record 41 of Set 7 | novosheshminsk
# Processing Record 42 of Set 7 | geraldton
# Processing Record 43 of Set 7 | vytegra
# Processing Record 44 of Set 7 | iracoubo
# Processing Record 45 of Set 7 | ponta delgada
# Processing Record 46 of Set 7 | pacific grove
# Processing Record 47 of Set 7 | kewanee
# Processing Record 48 of Set 7 | denpasar
# Processing Record 49 of Set 7 | tautira
# Processing Record 50 of Set 7 | kargopol
# Processing Record 1 of Set 8 | aitape
# Processing Record 2 of Set 8 | beloha
# Processing Record 3 of Set 8 | san rafael
# Processing Record 4 of Set 8 | grand gaube
# Processing Record 5 of Set 8 | xiaoweizhai
# Processing Record 6 of Set 8 | phan thiet
# Processing Record 7 of Set 8 | laval
# Processing Record 8 of Set 8 | san andres
# Processing Record 9 of Set 8 | oranjestad
# Processing Record 10 of Set 8 | korem
# Processing Record 11 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 8 | rio bananal
# Processing Record 13 of Set 8 | salto
# Processing Record 14 of Set 8 | kosh-agach
# Processing Record 15 of Set 8 | college
# Processing Record 16 of Set 8 | fort dodge
# Processing Record 17 of Set 8 | seymchan
# Processing Record 18 of Set 8 | atar
# Processing Record 19 of Set 8 | morro bay
# Processing Record 20 of Set 8 | almeirim
# Processing Record 21 of Set 8 | kekri
# Processing Record 22 of Set 8 | adrar
# Processing Record 23 of Set 8 | dubrovka
# Processing Record 24 of Set 8 | mezen
# Processing Record 25 of Set 8 | port hedland
# Processing Record 26 of Set 8 | ntcheu
# Processing Record 27 of Set 8 | nisia floresta
# Processing Record 28 of Set 8 | san vicente
# Processing Record 29 of Set 8 | tezu
# Processing Record 30 of Set 8 | severo-kurilsk
# Processing Record 31 of Set 8 | rundu
# Processing Record 32 of Set 8 | shunyi
# Processing Record 33 of Set 8 | nadym
# Processing Record 34 of Set 8 | san jeronimito
# Processing Record 35 of Set 8 | anatoli
# Processing Record 36 of Set 8 | iwanai
# Processing Record 37 of Set 8 | cherskiy
# Processing Record 38 of Set 8 | pangai
# Processing Record 39 of Set 8 | miraflores
# Processing Record 40 of Set 8 | atasu
# Processing Record 41 of Set 8 | rzhev
# Processing Record 42 of Set 8 | plettenberg bay
# Processing Record 43 of Set 8 | labuhan
# Processing Record 44 of Set 8 | lorengau
# Processing Record 45 of Set 8 | myshkin
# Processing Record 46 of Set 8 | stamsund
# City not found. Skipping...
# Processing Record 47 of Set 8 | la paz
# Processing Record 48 of Set 8 | malinyi
# Processing Record 49 of Set 8 | yuryevets
# Processing Record 50 of Set 8 | jangipur
# Processing Record 1 of Set 9 | dudinka
# Processing Record 2 of Set 9 | makung
# City not found. Skipping...
# Processing Record 3 of Set 9 | roros
# Processing Record 4 of Set 9 | marawi
# Processing Record 5 of Set 9 | souillac
# Processing Record 6 of Set 9 | hastings
# Processing Record 7 of Set 9 | gallipoli
# Processing Record 8 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 9 | pangnirtung
# Processing Record 10 of Set 9 | goderich
# Processing Record 11 of Set 9 | yangambi
# Processing Record 12 of Set 9 | grindavik
# Processing Record 13 of Set 9 | kenai
# Processing Record 14 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 15 of Set 9 | sansai
# City not found. Skipping...
# Processing Record 16 of Set 9 | azar shahr
# City not found. Skipping...
# Processing Record 17 of Set 9 | spearfish
# Processing Record 18 of Set 9 | northam
# Processing Record 19 of Set 9 | mugur-aksy
# Processing Record 20 of Set 9 | imbituba
# Processing Record 21 of Set 9 | orje
# Processing Record 22 of Set 9 | port hardy
# Processing Record 23 of Set 9 | kavaratti
# Processing Record 24 of Set 9 | grand-santi
# Processing Record 25 of Set 9 | bogo
# Processing Record 26 of Set 9 | lewiston
# Processing Record 27 of Set 9 | naze
# Processing Record 28 of Set 9 | khasan
# Processing Record 29 of Set 9 | nikolayevsk-na-amure
# Processing Record 30 of Set 9 | clyde river
# Processing Record 31 of Set 9 | puerto madryn
# Processing Record 32 of Set 9 | dryden
# Processing Record 33 of Set 9 | kruisfontein
# Processing Record 34 of Set 9 | iquitos
# Processing Record 35 of Set 9 | benghazi
# Processing Record 36 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 37 of Set 9 | tual
# Processing Record 38 of Set 9 | inta
# Processing Record 39 of Set 9 | opelousas
# Processing Record 40 of Set 9 | viedma
# Processing Record 41 of Set 9 | oyon
# Processing Record 42 of Set 9 | chapleau
# Processing Record 43 of Set 9 | comodoro rivadavia
# Processing Record 44 of Set 9 | kamaishi
# Processing Record 45 of Set 9 | kailua
# Processing Record 46 of Set 9 | dunedin
# Processing Record 47 of Set 9 | vila
# Processing Record 48 of Set 9 | viseu
# Processing Record 49 of Set 9 | terre haute
# Processing Record 50 of Set 9 | rawson
# Processing Record 1 of Set 10 | axim
# Processing Record 2 of Set 10 | north bend
# Processing Record 3 of Set 10 | te anau
# Processing Record 4 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 10 | balykshi
# Processing Record 6 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 10 | kralendijk
# Processing Record 8 of Set 10 | santa maria del oro
# Processing Record 9 of Set 10 | jorpeland
# Processing Record 10 of Set 10 | rio gallegos
# Processing Record 11 of Set 10 | kuala terengganu
# Processing Record 12 of Set 10 | russell
# Processing Record 13 of Set 10 | esperance
# Processing Record 14 of Set 10 | talara
# Processing Record 15 of Set 10 | prescott
# Processing Record 16 of Set 10 | eyl
# Processing Record 17 of Set 10 | riyaq
# City not found. Skipping...
# Processing Record 18 of Set 10 | dedougou
# Processing Record 19 of Set 10 | qandahar
# City not found. Skipping...
# Processing Record 20 of Set 10 | marv dasht
# City not found. Skipping...
# Processing Record 21 of Set 10 | namibe
# Processing Record 22 of Set 10 | laguna
# Processing Record 23 of Set 10 | pindamonhangaba
# Processing Record 24 of Set 10 | wana
# Processing Record 25 of Set 10 | shieli
# Processing Record 26 of Set 10 | maniitsoq
# Processing Record 27 of Set 10 | moussoro
# Processing Record 28 of Set 10 | tyukalinsk
# Processing Record 29 of Set 10 | lingyuan
# Processing Record 30 of Set 10 | jalu
# Processing Record 31 of Set 10 | tatsinskaya
# City not found. Skipping...
# Processing Record 32 of Set 10 | arlit
# Processing Record 33 of Set 10 | iskateley
# Processing Record 34 of Set 10 | marsaxlokk
# Processing Record 35 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 10 | gongzhuling
# Processing Record 37 of Set 10 | vizimyary
# City not found. Skipping...
# Processing Record 38 of Set 10 | metaxades
# Processing Record 39 of Set 10 | hobyo
# Processing Record 40 of Set 10 | neiafu
# Processing Record 41 of Set 10 | nichinan
# Processing Record 42 of Set 10 | evensk
# Processing Record 43 of Set 10 | vestmannaeyjar
# Processing Record 44 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 10 | hanzhong
# Processing Record 46 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 47 of Set 10 | corn island
# Processing Record 48 of Set 10 | carlagan
# Processing Record 49 of Set 10 | zhezkazgan
# Processing Record 50 of Set 10 | sarakhs
# Processing Record 1 of Set 11 | antalaha
# Processing Record 2 of Set 11 | portland
# Processing Record 3 of Set 11 | stornoway
# Processing Record 4 of Set 11 | ostersund
# Processing Record 5 of Set 11 | sao gabriel da cachoeira
# Processing Record 6 of Set 11 | bako
# Processing Record 7 of Set 11 | crateus
# Processing Record 8 of Set 11 | tulsa
# Processing Record 9 of Set 11 | seybaplaya
# Processing Record 10 of Set 11 | hasaki
# Processing Record 11 of Set 11 | krumovgrad
# Processing Record 12 of Set 11 | togur
# Processing Record 13 of Set 11 | calama
# Processing Record 14 of Set 11 | port augusta
# Processing Record 15 of Set 11 | virginia beach
# Processing Record 16 of Set 11 | halacho
# Processing Record 17 of Set 11 | amritsar
# Processing Record 18 of Set 11 | pallasovka
# Processing Record 19 of Set 11 | zadar
# Processing Record 20 of Set 11 | coquimbo
# Processing Record 21 of Set 11 | auburn
# Processing Record 22 of Set 11 | reshetylivka
# Processing Record 23 of Set 11 | oktyabrskiy
# Processing Record 24 of Set 11 | tlahualilo
# City not found. Skipping...
# Processing Record 25 of Set 11 | faya
# Processing Record 26 of Set 11 | itoman
# Processing Record 27 of Set 11 | fez
# Processing Record 28 of Set 11 | tokur
# Processing Record 29 of Set 11 | codrington
# Processing Record 30 of Set 11 | sanchazi
# Processing Record 31 of Set 11 | ouro preto do oeste
# Processing Record 32 of Set 11 | erzin
# Processing Record 33 of Set 11 | henties bay
# Processing Record 34 of Set 11 | dixon
# Processing Record 35 of Set 11 | weihe
# Processing Record 36 of Set 11 | malbork
# Processing Record 37 of Set 11 | huarmey
# Processing Record 38 of Set 11 | marevo
# Processing Record 39 of Set 11 | dargaville
# Processing Record 40 of Set 11 | turbat
# Processing Record 41 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 42 of Set 11 | manjacaze
# Processing Record 43 of Set 11 | dingtao
# Processing Record 44 of Set 11 | brae
# Processing Record 45 of Set 11 | surt
# Processing Record 46 of Set 11 | alyangula
# Processing Record 47 of Set 11 | yulara
# Processing Record 48 of Set 11 | magadan
# Processing Record 49 of Set 11 | nouadhibou
# Processing Record 50 of Set 11 | berbera
# Processing Record 1 of Set 12 | palotina
# Processing Record 2 of Set 12 | poum
# Processing Record 3 of Set 12 | kermanshah
# Processing Record 4 of Set 12 | mglin
# Processing Record 5 of Set 12 | kattivakkam
# Processing Record 6 of Set 12 | vanimo
# Processing Record 7 of Set 12 | skorodnoye
# Processing Record 8 of Set 12 | san patricio
# Processing Record 9 of Set 12 | salekhard
# Processing Record 10 of Set 12 | prince rupert
# Processing Record 11 of Set 12 | hervey bay
# Processing Record 12 of Set 12 | mahebourg
# Processing Record 13 of Set 12 | tres arroyos
# Processing Record 14 of Set 12 | sur
# Processing Record 15 of Set 12 | beringovskiy
# Processing Record 16 of Set 12 | taoudenni
# Processing Record 17 of Set 12 | muisne
# Processing Record 18 of Set 12 | acapulco
# Processing Record 19 of Set 12 | amapa
# Processing Record 20 of Set 12 | kudahuvadhoo
# Processing Record 21 of Set 12 | panaba
# Processing Record 22 of Set 12 | tombouctou
# Processing Record 23 of Set 12 | sao joao da barra
# Processing Record 24 of Set 12 | skreia
# Processing Record 25 of Set 12 | los alamos
# Processing Record 26 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 12 | burica
# City not found. Skipping...
# Processing Record 28 of Set 12 | arrifes
# Processing Record 29 of Set 12 | santa maria
# Processing Record 30 of Set 12 | elat
# Processing Record 31 of Set 12 | bubaque
# Processing Record 32 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 12 | sinnamary
# Processing Record 34 of Set 12 | jashpurnagar
# Processing Record 35 of Set 12 | aksarka
# Processing Record 36 of Set 12 | medicine hat
# Processing Record 37 of Set 12 | angra
# City not found. Skipping...
# Processing Record 38 of Set 12 | vila velha
# Processing Record 39 of Set 12 | teluknaga
# Processing Record 40 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 12 | gat
# Processing Record 42 of Set 12 | mainaguri
# Processing Record 43 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 12 | buala
# Processing Record 45 of Set 12 | mormugao
# Processing Record 46 of Set 12 | sibuco
# Processing Record 47 of Set 12 | verkhoyansk
# Processing Record 48 of Set 12 | goure
# Processing Record 49 of Set 12 | bougouni
# Processing Record 50 of Set 12 | makarov
# Processing Record 1 of Set 13 | babstovo
# Processing Record 2 of Set 13 | trairi
# Processing Record 3 of Set 13 | inhambane
# Processing Record 4 of Set 13 | richards bay
# Processing Record 5 of Set 13 | mehamn
# Processing Record 6 of Set 13 | bandar-e anzali
# Processing Record 7 of Set 13 | mecca
# Processing Record 8 of Set 13 | havre-saint-pierre
# Processing Record 9 of Set 13 | chake chake
# Processing Record 10 of Set 13 | yerbogachen
# Processing Record 11 of Set 13 | innisfail
# Processing Record 12 of Set 13 | kot addu
# Processing Record 13 of Set 13 | mbala
# Processing Record 14 of Set 13 | idappadi
# Processing Record 15 of Set 13 | saint-pierre
# Processing Record 16 of Set 13 | porbandar
# Processing Record 17 of Set 13 | garmsar
# Processing Record 18 of Set 13 | teguise
# Processing Record 19 of Set 13 | vila franca do campo
# Processing Record 20 of Set 13 | rancho palos verdes
# Processing Record 21 of Set 13 | xining
# Processing Record 22 of Set 13 | jardim
# Processing Record 23 of Set 13 | balaka
# Processing Record 24 of Set 13 | russas
# Processing Record 25 of Set 13 | mingshui
# Processing Record 26 of Set 13 | clyde
# Processing Record 27 of Set 13 | kilindoni
# Processing Record 28 of Set 13 | hambantota
# Processing Record 29 of Set 13 | tolaga bay
# Processing Record 30 of Set 13 | mayo
# Processing Record 31 of Set 13 | miri
# Processing Record 32 of Set 13 | hailar
# Processing Record 33 of Set 13 | yarada
# Processing Record 34 of Set 13 | yarim
# Processing Record 35 of Set 13 | arica
# Processing Record 36 of Set 13 | yara
# Processing Record 37 of Set 13 | sumbe
# Processing Record 38 of Set 13 | xapuri
# Processing Record 39 of Set 13 | verkhnyaya inta
# Processing Record 40 of Set 13 | sao felix do xingu
# Processing Record 41 of Set 13 | collie
# Processing Record 42 of Set 13 | mechetinskaya
# Processing Record 43 of Set 13 | tabas
# Processing Record 44 of Set 13 | tanout
# Processing Record 45 of Set 13 | umarkhed
# Processing Record 46 of Set 13 | kisangani
# Processing Record 47 of Set 13 | marsh harbour
# Processing Record 48 of Set 13 | naron
# Processing Record 49 of Set 13 | huangnihe
# Processing Record 50 of Set 13 | rusape
# Processing Record 1 of Set 14 | shingu
# Processing Record 2 of Set 14 | asau
# Processing Record 3 of Set 14 | mikhaylovka
# Processing Record 4 of Set 14 | sulangan
# Processing Record 5 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 14 | birao
# Processing Record 7 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 14 | lashio
# Processing Record 9 of Set 14 | quatre cocos
# Processing Record 10 of Set 14 | gazli
# Processing Record 11 of Set 14 | port macquarie
# Processing Record 12 of Set 14 | tecoanapa
# Processing Record 13 of Set 14 | camopi
# Processing Record 14 of Set 14 | guanare
# Processing Record 15 of Set 14 | sao jose da coroa grande
# Processing Record 16 of Set 14 | puerto madero
# Processing Record 17 of Set 14 | teeli
# Processing Record 18 of Set 14 | mantua
# Processing Record 19 of Set 14 | santander
# Processing Record 20 of Set 14 | catalina
# Processing Record 21 of Set 14 | chiautla
# Processing Record 22 of Set 14 | somerset west
# Processing Record 23 of Set 14 | basco
# Processing Record 24 of Set 14 | anadyr
# Processing Record 25 of Set 14 | robe
# Processing Record 26 of Set 14 | berlevag
# Processing Record 27 of Set 14 | porto novo
# Processing Record 28 of Set 14 | bouza
# Processing Record 29 of Set 14 | saint-jerome
# Processing Record 30 of Set 14 | launceston
# Processing Record 31 of Set 14 | orapa
# Processing Record 32 of Set 14 | sangar
# Processing Record 33 of Set 14 | benguela
# Processing Record 34 of Set 14 | bogande
# Processing Record 35 of Set 14 | emba
# Processing Record 36 of Set 14 | aksu
# Processing Record 37 of Set 14 | tsiroanomandidy
# Processing Record 38 of Set 14 | male
# Processing Record 39 of Set 14 | unirea
# Processing Record 40 of Set 14 | raton
# Processing Record 41 of Set 14 | prata
# Processing Record 42 of Set 14 | abeche
# Processing Record 43 of Set 14 | khovu-aksy
# Processing Record 44 of Set 14 | jiwani
# Processing Record 45 of Set 14 | ihosy
# Processing Record 46 of Set 14 | dubna
# Processing Record 47 of Set 14 | riyadh
# Processing Record 48 of Set 14 | egvekinot
# Processing Record 49 of Set 14 | dzaoudzi
# Processing Record 50 of Set 14 | asilah
# Processing Record 1 of Set 15 | ende
# Processing Record 2 of Set 15 | jumla
# Processing Record 3 of Set 15 | valvedditturai
# Processing Record 4 of Set 15 | taganak
# Processing Record 5 of Set 15 | mpongwe
# Processing Record 6 of Set 15 | saint-augustin
# Processing Record 7 of Set 15 | santiago
# Processing Record 8 of Set 15 | flinders
# Processing Record 9 of Set 15 | hudiksvall
# Processing Record 10 of Set 15 | san quintin
# Processing Record 11 of Set 15 | tonj
# Processing Record 12 of Set 15 | dong hoi
# Processing Record 13 of Set 15 | socorro
# Processing Record 14 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 15 | talcahuano
# Processing Record 16 of Set 15 | fare
# Processing Record 17 of Set 15 | awjilah
# Processing Record 18 of Set 15 | maumere
# Processing Record 19 of Set 15 | vangaindrano
# Processing Record 20 of Set 15 | kishcha
# Processing Record 21 of Set 15 | tete
# Processing Record 22 of Set 15 | port hawkesbury
# Processing Record 23 of Set 15 | dmitriyevka
# Processing Record 24 of Set 15 | vaitape
# Processing Record 25 of Set 15 | lerwick
# Processing Record 26 of Set 15 | isla mujeres
# Processing Record 27 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 28 of Set 15 | otradnoye
# Processing Record 29 of Set 15 | calbuco
# Processing Record 30 of Set 15 | biak
# Processing Record 31 of Set 15 | dakar
# Processing Record 32 of Set 15 | tondano
# Processing Record 33 of Set 15 | kaseda
# Processing Record 34 of Set 15 | kismayo
# Processing Record 35 of Set 15 | colac
# Processing Record 36 of Set 15 | turayf
# Processing Record 37 of Set 15 | gizo
# Processing Record 38 of Set 15 | lagos
# Processing Record 39 of Set 15 | maputo
# Processing Record 40 of Set 15 | san miguel
# Processing Record 41 of Set 15 | leningradskiy
# Processing Record 42 of Set 15 | baryatino
# Processing Record 43 of Set 15 | kot diji
# Processing Record 44 of Set 15 | sibolga
# Processing Record 45 of Set 15 | sayabec
# City not found. Skipping...
# Processing Record 46 of Set 15 | ixtapa
# Processing Record 47 of Set 15 | sovetskiy
# Processing Record 48 of Set 15 | olenegorsk
# Processing Record 49 of Set 15 | alcala de henares
# Processing Record 50 of Set 15 | caraballeda
# Processing Record 1 of Set 16 | tilichiki
# Processing Record 2 of Set 16 | kuala lipis
# Processing Record 3 of Set 16 | vestmanna
# Processing Record 4 of Set 16 | ayame
# Processing Record 5 of Set 16 | pathein
# Processing Record 6 of Set 16 | shache
# Processing Record 7 of Set 16 | takoradi
# Processing Record 8 of Set 16 | saint anthony
# Processing Record 9 of Set 16 | cockburn town
# Processing Record 10 of Set 16 | broken hill
# Processing Record 11 of Set 16 | talaya
# Processing Record 12 of Set 16 | mocuba
# Processing Record 13 of Set 16 | porto tolle
# Processing Record 14 of Set 16 | tura
# Processing Record 15 of Set 16 | olinda
# Processing Record 16 of Set 16 | karatau
# Processing Record 17 of Set 16 | bandar
# Processing Record 18 of Set 16 | baoding
# Processing Record 19 of Set 16 | tabou
# Processing Record 20 of Set 16 | bindura
# Processing Record 21 of Set 16 | telimele
# Processing Record 22 of Set 16 | saint joseph
# Processing Record 23 of Set 16 | cheremkhovo
# Processing Record 24 of Set 16 | troy
# Processing Record 25 of Set 16 | gravdal
# Processing Record 26 of Set 16 | sidney
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 714

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Sorong  -0.8833  131.2500     79.41        81         100
# 1          Albany  42.6001  -73.9662     46.17        43           4
# 2          Avarua -21.2078 -159.7750     73.45        94          85
# 3        Cidreira -30.1811  -50.2056     71.80        68           5
# 4       Jamestown  42.0970  -79.2353     42.03        48           0
# 5           Vaini -21.2000 -175.2000     71.76       100          20
# 6    Punta Arenas -53.1500  -70.9167     42.91        93         100
# 7  Terekli-Mekteb  44.1671   45.8698     60.76        53          16
# 8         Rikitea -23.1203 -134.9692     74.17        57          48
# 9         Ushuaia -54.8000  -68.3000     42.42        93         100
#
#    Wind Speed Country                 Date              Description
# 0        4.83      ID  2022-04-02 16:39:33          overcast clouds
# 1        4.00      US  2022-04-02 16:37:53                clear sky
# 2        2.30      CK  2022-04-02 16:39:33          overcast clouds
# 3       13.80      BR  2022-04-02 16:39:33                clear sky
# 4        4.61      US  2022-04-02 16:39:34                clear sky
# 5        0.00      TO  2022-04-02 16:39:34               few clouds
# 6       12.66      CL  2022-04-02 16:36:05  light intensity drizzle
# 7        4.09      RU  2022-04-02 16:39:34               few clouds
# 8        8.19      PF  2022-04-02 16:39:35         scattered clouds
# 9        6.91      AR  2022-04-02 16:39:35                  drizzle

# %%
# Rearrange columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0          Sorong      ID  2022-04-02 16:39:33  -0.8833  131.2500     79.41
# 1          Albany      US  2022-04-02 16:37:53  42.6001  -73.9662     46.17
# 2          Avarua      CK  2022-04-02 16:39:33 -21.2078 -159.7750     73.45
# 3        Cidreira      BR  2022-04-02 16:39:33 -30.1811  -50.2056     71.80
# 4       Jamestown      US  2022-04-02 16:39:34  42.0970  -79.2353     42.03
# 5           Vaini      TO  2022-04-02 16:39:34 -21.2000 -175.2000     71.76
# 6    Punta Arenas      CL  2022-04-02 16:36:05 -53.1500  -70.9167     42.91
# 7  Terekli-Mekteb      RU  2022-04-02 16:39:34  44.1671   45.8698     60.76
# 8         Rikitea      PF  2022-04-02 16:39:35 -23.1203 -134.9692     74.17
# 9         Ushuaia      AR  2022-04-02 16:39:35 -54.8000  -68.3000     42.42
#
#    Humidity  Cloudiness  Wind Speed              Description
# 0        81         100        4.83          overcast clouds
# 1        43           4        4.00                clear sky
# 2        94          85        2.30          overcast clouds
# 3        68           5       13.80                clear sky
# 4        48           0        4.61                clear sky
# 5       100          20        0.00               few clouds
# 6        93         100       12.66  light intensity drizzle
# 7        53          16        4.09               few clouds
# 8        57          48        8.19         scattered clouds
# 9        93         100        6.91                  drizzle

# %%
#Output variable/ file name
output_file="./WeatherPy_Database.csv"

#Output to CSV
city_data_df.to_csv(output_file, index_label="City_ID")

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 596

# %%
# import the requests library
import requests

# import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities - try-except block learning
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kerema
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | yerbogachen
# Processing Record 4 of Set 1 | palana
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | west wendover
# Processing Record 8 of Set 1 | zachagansk
# City not found. Skipping...
# Processing Record 9 of Set 1 | narsaq
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | manono
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | kaeo
# Processing Record 16 of Set 1 | biak
# Processing Record 17 of Set 1 | urengoy
# Processing Record 18 of Set 1 | ixtapa
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | touros
# Processing Record 22 of Set 1 | jiblah
# Processing Record 23 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 1 | barranca
# Processing Record 25 of Set 1 | sokolo
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 1 | itarema
# Processing Record 29 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | siswa bazar
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | portland
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | bengkulu
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | zhaotong
# Processing Record 44 of Set 1 | aklavik
# Processing Record 45 of Set 1 | dunedin
# Processing Record 46 of Set 1 | sao jose da coroa grande
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | norman wells
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | carutapera
# Processing Record 1 of Set 2 | raudeberg
# Processing Record 2 of Set 2 | abashiri
# Processing Record 3 of Set 2 | pemex
# Processing Record 4 of Set 2 | tuatapere
# Processing Record 5 of Set 2 | praia da vitoria
# Processing Record 6 of Set 2 | acajutla
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | scottsbluff
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | victoria point
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | cap-aux-meules
# Processing Record 13 of Set 2 | griffith
# Processing Record 14 of Set 2 | shache
# Processing Record 15 of Set 2 | leningradskiy
# Processing Record 16 of Set 2 | harper
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | carupano
# Processing Record 20 of Set 2 | salalah
# Processing Record 21 of Set 2 | marawi
# Processing Record 22 of Set 2 | maragogi
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | the valley
# Processing Record 25 of Set 2 | mitu
# Processing Record 26 of Set 2 | libertad
# Processing Record 27 of Set 2 | vaitape
# Processing Record 28 of Set 2 | mudon
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | buraydah
# Processing Record 33 of Set 2 | kruisfontein
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | avera
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | nanortalik
# Processing Record 38 of Set 2 | souillac
# Processing Record 39 of Set 2 | bubaque
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | gat
# Processing Record 42 of Set 2 | codrington
# Processing Record 43 of Set 2 | straumen
# Processing Record 44 of Set 2 | castellammare del golfo
# Processing Record 45 of Set 2 | nyurba
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | paraiso
# Processing Record 48 of Set 2 | kahului
# Processing Record 49 of Set 2 | havoysund
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 3 | faanui
# Processing Record 3 of Set 3 | rosarito
# Processing Record 4 of Set 3 | izberbash
# Processing Record 5 of Set 3 | barkot
# Processing Record 6 of Set 3 | khatanga
# Processing Record 7 of Set 3 | kabo
# Processing Record 8 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 3 | amuntai
# Processing Record 10 of Set 3 | constitucion
# Processing Record 11 of Set 3 | dekoa
# City not found. Skipping...
# Processing Record 12 of Set 3 | cabra
# Processing Record 13 of Set 3 | port macquarie
# Processing Record 14 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | san pedro
# Processing Record 18 of Set 3 | walvis bay
# Processing Record 19 of Set 3 | bethel
# Processing Record 20 of Set 3 | saskylakh
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | albany
# Processing Record 23 of Set 3 | chumikan
# Processing Record 24 of Set 3 | nabire
# Processing Record 25 of Set 3 | cayenne
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | smithers
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | noyabrsk
# Processing Record 30 of Set 3 | dyadkovskaya
# City not found. Skipping...
# Processing Record 31 of Set 3 | yozgat
# Processing Record 32 of Set 3 | ternate
# Processing Record 33 of Set 3 | angoche
# Processing Record 34 of Set 3 | laguna
# Processing Record 35 of Set 3 | college
# Processing Record 36 of Set 3 | bredasdorp
# Processing Record 37 of Set 3 | yangjiang
# Processing Record 38 of Set 3 | albanel
# Processing Record 39 of Set 3 | cape town
# Processing Record 40 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 3 | mizdah
# Processing Record 42 of Set 3 | thompson
# Processing Record 43 of Set 3 | sabang
# Processing Record 44 of Set 3 | hami
# Processing Record 45 of Set 3 | karratha
# Processing Record 46 of Set 3 | puerto el triunfo
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | pitimbu
# Processing Record 49 of Set 3 | gravdal
# Processing Record 50 of Set 3 | luderitz
# Processing Record 1 of Set 4 | victoria
# Processing Record 2 of Set 4 | hovd
# Processing Record 3 of Set 4 | fairbanks
# Processing Record 4 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 4 | marrakesh
# Processing Record 6 of Set 4 | kidal
# Processing Record 7 of Set 4 | tessalit
# Processing Record 8 of Set 4 | bollnas
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | adamas
# Processing Record 11 of Set 4 | teya
# Processing Record 12 of Set 4 | mana
# Processing Record 13 of Set 4 | sobolevo
# Processing Record 14 of Set 4 | anadyr
# Processing Record 15 of Set 4 | nhulunbuy
# Processing Record 16 of Set 4 | aswan
# Processing Record 17 of Set 4 | nome
# Processing Record 18 of Set 4 | upernavik
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | arraial do cabo
# Processing Record 21 of Set 4 | olafsvik
# Processing Record 22 of Set 4 | baruun-urt
# Processing Record 23 of Set 4 | cidreira
# Processing Record 24 of Set 4 | tucuman
# Processing Record 25 of Set 4 | viedma
# Processing Record 26 of Set 4 | east london
# Processing Record 27 of Set 4 | carnarvon
# Processing Record 28 of Set 4 | saint-georges
# Processing Record 29 of Set 4 | hamilton
# Processing Record 30 of Set 4 | chalakudi
# Processing Record 31 of Set 4 | lodwar
# Processing Record 32 of Set 4 | anloga
# Processing Record 33 of Set 4 | hay river
# Processing Record 34 of Set 4 | yar-sale
# Processing Record 35 of Set 4 | scalloway
# City not found. Skipping...
# Processing Record 36 of Set 4 | margate
# Processing Record 37 of Set 4 | vao
# Processing Record 38 of Set 4 | paamiut
# Processing Record 39 of Set 4 | pangody
# Processing Record 40 of Set 4 | sumenep
# Processing Record 41 of Set 4 | pinawa
# Processing Record 42 of Set 4 | karad
# Processing Record 43 of Set 4 | los llanos de aridane
# Processing Record 44 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 4 | yellowknife
# Processing Record 46 of Set 4 | kavieng
# Processing Record 47 of Set 4 | inhambane
# Processing Record 48 of Set 4 | chuy
# Processing Record 49 of Set 4 | opuwo
# Processing Record 50 of Set 4 | ashington
# Processing Record 1 of Set 5 | puerto narino
# Processing Record 2 of Set 5 | whitley bay
# Processing Record 3 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 5 | katsuura
# Processing Record 5 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 6 of Set 5 | hualmay
# Processing Record 7 of Set 5 | ilulissat
# Processing Record 8 of Set 5 | lavrentiya
# Processing Record 9 of Set 5 | iqaluit
# Processing Record 10 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 5 | bathsheba
# Processing Record 12 of Set 5 | tiksi
# Processing Record 13 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 14 of Set 5 | isangel
# Processing Record 15 of Set 5 | goundam
# Processing Record 16 of Set 5 | clyde river
# Processing Record 17 of Set 5 | rockhampton
# Processing Record 18 of Set 5 | port moresby
# Processing Record 19 of Set 5 | cherskiy
# Processing Record 20 of Set 5 | mandali
# Processing Record 21 of Set 5 | coquimbo
# Processing Record 22 of Set 5 | sayville
# Processing Record 23 of Set 5 | wewak
# Processing Record 24 of Set 5 | xiuyan
# Processing Record 25 of Set 5 | talnakh
# Processing Record 26 of Set 5 | esperance
# Processing Record 27 of Set 5 | muros
# Processing Record 28 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 5 | suntar
# Processing Record 30 of Set 5 | visnes
# Processing Record 31 of Set 5 | georgetown
# Processing Record 32 of Set 5 | bandarbeyla
# Processing Record 33 of Set 5 | lensk
# Processing Record 34 of Set 5 | covington
# Processing Record 35 of Set 5 | skjervoy
# Processing Record 36 of Set 5 | calvia
# Processing Record 37 of Set 5 | alice springs
# Processing Record 38 of Set 5 | evensk
# Processing Record 39 of Set 5 | bosaso
# Processing Record 40 of Set 5 | buarcos
# Processing Record 41 of Set 5 | candawaga
# City not found. Skipping...
# Processing Record 42 of Set 5 | bilibino
# Processing Record 43 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 5 | langarud
# Processing Record 45 of Set 5 | sakti
# Processing Record 46 of Set 5 | banikoara
# Processing Record 47 of Set 5 | kalmunai
# Processing Record 48 of Set 5 | taree
# Processing Record 49 of Set 5 | lasa
# Processing Record 50 of Set 5 | port hardy
# Processing Record 1 of Set 6 | tual
# Processing Record 2 of Set 6 | denpasar
# Processing Record 3 of Set 6 | barra do bugres
# Processing Record 4 of Set 6 | maridi
# Processing Record 5 of Set 6 | saldanha
# Processing Record 6 of Set 6 | kanker
# Processing Record 7 of Set 6 | dormidontovka
# Processing Record 8 of Set 6 | prince rupert
# Processing Record 9 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 6 | vrangel
# Processing Record 11 of Set 6 | keta
# Processing Record 12 of Set 6 | lagoa
# Processing Record 13 of Set 6 | maldonado
# Processing Record 14 of Set 6 | jacareacanga
# Processing Record 15 of Set 6 | palmer
# Processing Record 16 of Set 6 | benghazi
# Processing Record 17 of Set 6 | mayya
# Processing Record 18 of Set 6 | pisco
# Processing Record 19 of Set 6 | buritizeiro
# Processing Record 20 of Set 6 | san patricio
# Processing Record 21 of Set 6 | qaqortoq
# Processing Record 22 of Set 6 | fort nelson
# Processing Record 23 of Set 6 | shaunavon
# Processing Record 24 of Set 6 | puerto leguizamo
# Processing Record 25 of Set 6 | malm
# Processing Record 26 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 27 of Set 6 | iracoubo
# Processing Record 28 of Set 6 | jaciara
# Processing Record 29 of Set 6 | gizo
# Processing Record 30 of Set 6 | provideniya
# Processing Record 31 of Set 6 | ponta do sol
# Processing Record 32 of Set 6 | nueve de julio
# Processing Record 33 of Set 6 | saint paul
# Processing Record 34 of Set 6 | lompoc
# Processing Record 35 of Set 6 | lerik
# Processing Record 36 of Set 6 | san cristobal
# Processing Record 37 of Set 6 | lanigan
# Processing Record 38 of Set 6 | pevek
# Processing Record 39 of Set 6 | taoudenni
# Processing Record 40 of Set 6 | cabo san lucas
# Processing Record 41 of Set 6 | bonthe
# Processing Record 42 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 43 of Set 6 | talcahuano
# Processing Record 44 of Set 6 | port lincoln
# Processing Record 45 of Set 6 | outlook
# Processing Record 46 of Set 6 | picton
# Processing Record 47 of Set 6 | shirokiy
# Processing Record 48 of Set 6 | san-pedro
# Processing Record 49 of Set 6 | manjacaze
# Processing Record 50 of Set 6 | nigde
# Processing Record 1 of Set 7 | liniere
# City not found. Skipping...
# Processing Record 2 of Set 7 | hwange
# Processing Record 3 of Set 7 | ileza
# Processing Record 4 of Set 7 | birao
# Processing Record 5 of Set 7 | linqiong
# Processing Record 6 of Set 7 | lahaina
# Processing Record 7 of Set 7 | manaus
# Processing Record 8 of Set 7 | mogadishu
# Processing Record 9 of Set 7 | faya
# Processing Record 10 of Set 7 | puerto gaitan
# Processing Record 11 of Set 7 | gazli
# Processing Record 12 of Set 7 | alofi
# Processing Record 13 of Set 7 | loubomo
# Processing Record 14 of Set 7 | shelburne
# Processing Record 15 of Set 7 | aloja
# Processing Record 16 of Set 7 | arman
# Processing Record 17 of Set 7 | vestmannaeyjar
# Processing Record 18 of Set 7 | ancud
# Processing Record 19 of Set 7 | itaituba
# Processing Record 20 of Set 7 | umm kaddadah
# Processing Record 21 of Set 7 | egvekinot
# Processing Record 22 of Set 7 | biloela
# Processing Record 23 of Set 7 | fukue
# Processing Record 24 of Set 7 | srednekolymsk
# Processing Record 25 of Set 7 | pishin
# Processing Record 26 of Set 7 | takoradi
# Processing Record 27 of Set 7 | machilipatnam
# Processing Record 28 of Set 7 | chapais
# Processing Record 29 of Set 7 | igdir
# Processing Record 30 of Set 7 | tomatlan
# Processing Record 31 of Set 7 | klaksvik
# Processing Record 32 of Set 7 | kenai
# Processing Record 33 of Set 7 | kununurra
# Processing Record 34 of Set 7 | shingu
# Processing Record 35 of Set 7 | mehamn
# Processing Record 36 of Set 7 | samarinda
# Processing Record 37 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 7 | cairns
# Processing Record 39 of Set 7 | cruzeiro do sul
# Processing Record 40 of Set 7 | guerrero negro
# Processing Record 41 of Set 7 | mhlambanyatsi
# Processing Record 42 of Set 7 | san carlos de bariloche
# Processing Record 43 of Set 7 | sibu
# Processing Record 44 of Set 7 | xai-xai
# Processing Record 45 of Set 7 | grindavik
# Processing Record 46 of Set 7 | letterkenny
# Processing Record 47 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 7 | umm lajj
# Processing Record 49 of Set 7 | amapa
# Processing Record 50 of Set 7 | dikson
# Processing Record 1 of Set 8 | ahipara
# Processing Record 2 of Set 8 | zhigansk
# Processing Record 3 of Set 8 | northam
# Processing Record 4 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 8 | potam
# Processing Record 6 of Set 8 | mahon
# Processing Record 7 of Set 8 | teguldet
# Processing Record 8 of Set 8 | bambanglipuro
# Processing Record 9 of Set 8 | airai
# Processing Record 10 of Set 8 | fortuna
# Processing Record 11 of Set 8 | la ronge
# Processing Record 12 of Set 8 | husavik
# Processing Record 13 of Set 8 | borovsk
# Processing Record 14 of Set 8 | buala
# Processing Record 15 of Set 8 | whitehorse
# Processing Record 16 of Set 8 | ibotirama
# Processing Record 17 of Set 8 | biltine
# Processing Record 18 of Set 8 | semey
# Processing Record 19 of Set 8 | dole
# Processing Record 20 of Set 8 | parabel
# Processing Record 21 of Set 8 | changli
# Processing Record 22 of Set 8 | atar
# Processing Record 23 of Set 8 | duldurga
# Processing Record 24 of Set 8 | mecca
# Processing Record 25 of Set 8 | matelandia
# Processing Record 26 of Set 8 | ranong
# Processing Record 27 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 8 | tura
# Processing Record 29 of Set 8 | semikarakorsk
# Processing Record 30 of Set 8 | mersing
# Processing Record 31 of Set 8 | sao felix do xingu
# Processing Record 32 of Set 8 | telbang
# Processing Record 33 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 8 | cap malheureux
# Processing Record 36 of Set 8 | zenzeli
# Processing Record 37 of Set 8 | samarai
# Processing Record 38 of Set 8 | lima
# Processing Record 39 of Set 8 | ostrovnoy
# Processing Record 40 of Set 8 | lufkin
# Processing Record 41 of Set 8 | gurgentepe
# Processing Record 42 of Set 8 | san quintin
# Processing Record 43 of Set 8 | richards bay
# Processing Record 44 of Set 8 | hofn
# Processing Record 45 of Set 8 | banos
# Processing Record 46 of Set 8 | alexandria
# Processing Record 47 of Set 8 | leshukonskoye
# Processing Record 48 of Set 8 | juegang
# Processing Record 49 of Set 8 | safford
# Processing Record 50 of Set 8 | makakilo city
# Processing Record 1 of Set 9 | muroto
# Processing Record 2 of Set 9 | kuala kedah
# Processing Record 3 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 4 of Set 9 | bintulu
# Processing Record 5 of Set 9 | tautira
# Processing Record 6 of Set 9 | tarauaca
# Processing Record 7 of Set 9 | rawson
# Processing Record 8 of Set 9 | solnechnyy
# Processing Record 9 of Set 9 | karema
# Processing Record 10 of Set 9 | mvomero
# Processing Record 11 of Set 9 | virtsu
# Processing Record 12 of Set 9 | kibala
# Processing Record 13 of Set 9 | thinadhoo
# Processing Record 14 of Set 9 | saint-pierre
# Processing Record 15 of Set 9 | yangambi
# Processing Record 16 of Set 9 | mandalgovi
# Processing Record 17 of Set 9 | flinders
# Processing Record 18 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 9 | musoma
# Processing Record 20 of Set 9 | mahanoro
# Processing Record 21 of Set 9 | grand gaube
# Processing Record 22 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 9 | nyrob
# Processing Record 24 of Set 9 | la rioja
# Processing Record 25 of Set 9 | knyaze-volkonskoye
# Processing Record 26 of Set 9 | kalangala
# Processing Record 27 of Set 9 | perth
# Processing Record 28 of Set 9 | tornio
# Processing Record 29 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 9 | lincoln
# Processing Record 31 of Set 9 | saint-augustin
# Processing Record 32 of Set 9 | te anau
# Processing Record 33 of Set 9 | sangar
# Processing Record 34 of Set 9 | tokmak
# Processing Record 35 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 9 | moose factory
# Processing Record 37 of Set 9 | jardim
# Processing Record 38 of Set 9 | tome-acu
# City not found. Skipping...
# Processing Record 39 of Set 9 | pilos
# City not found. Skipping...
# Processing Record 40 of Set 9 | kushmurun
# Processing Record 41 of Set 9 | kalakamati
# Processing Record 42 of Set 9 | kilimatinde
# Processing Record 43 of Set 9 | concepcion del oro
# Processing Record 44 of Set 9 | wanning
# Processing Record 45 of Set 9 | farah
# Processing Record 46 of Set 9 | svetlyy
# Processing Record 47 of Set 9 | ereymentau
# Processing Record 48 of Set 9 | magadi
# Processing Record 49 of Set 9 | yulara
# Processing Record 50 of Set 9 | wahiawa
# Processing Record 1 of Set 10 | autun
# Processing Record 2 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 3 of Set 10 | sur
# Processing Record 4 of Set 10 | virginia beach
# Processing Record 5 of Set 10 | sernur
# Processing Record 6 of Set 10 | khuzhir
# Processing Record 7 of Set 10 | wangqing
# Processing Record 8 of Set 10 | aldan
# Processing Record 9 of Set 10 | itoman
# Processing Record 10 of Set 10 | kampene
# Processing Record 11 of Set 10 | nerchinskiy zavod
# Processing Record 12 of Set 10 | haines junction
# Processing Record 13 of Set 10 | yalvac
# Processing Record 14 of Set 10 | bogandinskiy
# Processing Record 15 of Set 10 | ulladulla
# Processing Record 16 of Set 10 | corner brook
# Processing Record 17 of Set 10 | yaan
# Processing Record 18 of Set 10 | doha
# Processing Record 19 of Set 10 | acapulco
# Processing Record 20 of Set 10 | enid
# Processing Record 21 of Set 10 | batagay-alyta
# Processing Record 22 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 23 of Set 10 | isiro
# Processing Record 24 of Set 10 | shitkino
# Processing Record 25 of Set 10 | napasar
# Processing Record 26 of Set 10 | chilca
# Processing Record 27 of Set 10 | hermiston
# Processing Record 28 of Set 10 | cooma
# Processing Record 29 of Set 10 | san bartolome de tirajana
# Processing Record 30 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 31 of Set 10 | ipueiras
# Processing Record 32 of Set 10 | kirkwall
# Processing Record 33 of Set 10 | natchitoches
# Processing Record 34 of Set 10 | micheweni
# Processing Record 35 of Set 10 | eureka
# Processing Record 36 of Set 10 | solin
# Processing Record 37 of Set 10 | kushalgarh
# Processing Record 38 of Set 10 | pacific grove
# Processing Record 39 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 40 of Set 10 | talpa
# Processing Record 41 of Set 10 | illela
# Processing Record 42 of Set 10 | lumberton
# Processing Record 43 of Set 10 | zeliezovce
# Processing Record 44 of Set 10 | bom jesus
# Processing Record 45 of Set 10 | hohhot
# Processing Record 46 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 10 | shenkursk
# Processing Record 48 of Set 10 | macapa
# Processing Record 49 of Set 10 | lagunillas
# Processing Record 50 of Set 10 | melito di porto salvo
# Processing Record 1 of Set 11 | damietta
# Processing Record 2 of Set 11 | westport
# Processing Record 3 of Set 11 | turukhansk
# Processing Record 4 of Set 11 | bushenyi
# Processing Record 5 of Set 11 | sibolga
# Processing Record 6 of Set 11 | kirakira
# Processing Record 7 of Set 11 | bushehr
# Processing Record 8 of Set 11 | geraldton
# Processing Record 9 of Set 11 | wattegama
# Processing Record 10 of Set 11 | yanam
# Processing Record 11 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 12 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 11 | chokurdakh
# Processing Record 14 of Set 11 | wajir
# Processing Record 15 of Set 11 | pasni
# Processing Record 16 of Set 11 | auki
# Processing Record 17 of Set 11 | lavassaare
# Processing Record 18 of Set 11 | kaoma
# Processing Record 19 of Set 11 | sanary-sur-mer
# Processing Record 20 of Set 11 | puerto escondido
# Processing Record 21 of Set 11 | haukipudas
# Processing Record 22 of Set 11 | vardo
# Processing Record 23 of Set 11 | liepaja
# Processing Record 24 of Set 11 | luena
# Processing Record 25 of Set 11 | neiafu
# Processing Record 26 of Set 11 | juba
# Processing Record 27 of Set 11 | bloemfontein
# Processing Record 28 of Set 11 | champaign
# Processing Record 29 of Set 11 | berlevag
# Processing Record 30 of Set 11 | worland
# Processing Record 31 of Set 11 | tashla
# Processing Record 32 of Set 11 | roald
# Processing Record 33 of Set 11 | maniitsoq
# Processing Record 34 of Set 11 | vila velha
# Processing Record 35 of Set 11 | kattivakkam
# Processing Record 36 of Set 11 | listica
# City not found. Skipping...
# Processing Record 37 of Set 11 | hereford
# Processing Record 38 of Set 11 | alugan
# Processing Record 39 of Set 11 | oussouye
# Processing Record 40 of Set 11 | sexsmith
# Processing Record 41 of Set 11 | athabasca
# Processing Record 42 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 11 | vanimo
# Processing Record 44 of Set 11 | jumla
# Processing Record 45 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 46 of Set 11 | kurchum
# Processing Record 47 of Set 11 | beloha
# Processing Record 48 of Set 11 | kavaratti
# Processing Record 49 of Set 11 | teguise
# Processing Record 50 of Set 11 | mugur-aksy
# Processing Record 1 of Set 12 | kyren
# Processing Record 2 of Set 12 | saint-joseph
# Processing Record 3 of Set 12 | kangaatsiaq
# Processing Record 4 of Set 12 | yatou
# Processing Record 5 of Set 12 | soller
# Processing Record 6 of Set 12 | chulman
# Processing Record 7 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 12 | katherine
# Processing Record 9 of Set 12 | elko
# Processing Record 10 of Set 12 | vallenar
# Processing Record 11 of Set 12 | belmonte
# Processing Record 12 of Set 12 | contamana
# Processing Record 13 of Set 12 | henties bay
# Processing Record 14 of Set 12 | katangli
# Processing Record 15 of Set 12 | svetlaya
# Processing Record 16 of Set 12 | hasaki
# Processing Record 17 of Set 12 | sarankhola
# Processing Record 18 of Set 12 | huancabamba
# Processing Record 19 of Set 12 | weihe
# Processing Record 20 of Set 12 | yukamenskoye
# Processing Record 21 of Set 12 | birnin kebbi
# Processing Record 22 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 12 | turquel
# Processing Record 25 of Set 12 | hurzuf
# Processing Record 26 of Set 12 | san carlos
# Processing Record 27 of Set 12 | necochea
# Processing Record 28 of Set 12 | chicama
# Processing Record 29 of Set 12 | tres arroyos
# Processing Record 30 of Set 12 | watsa
# Processing Record 31 of Set 12 | quatre cocos
# Processing Record 32 of Set 12 | mendahara
# City not found. Skipping...
# Processing Record 33 of Set 12 | beyneu
# Processing Record 34 of Set 12 | padang
# Processing Record 35 of Set 12 | severnoye
# Processing Record 36 of Set 12 | nuuk
# Processing Record 37 of Set 12 | camopi
# Processing Record 38 of Set 12 | xining
# Processing Record 39 of Set 12 | ilebo
# Processing Record 40 of Set 12 | dudinka
# Processing Record 41 of Set 12 | luanda
# Processing Record 42 of Set 12 | kathu
# Processing Record 43 of Set 12 | trincomalee
# Processing Record 44 of Set 12 | lufilufi
# Processing Record 45 of Set 12 | smoky lake
# Processing Record 46 of Set 12 | aporawan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 538

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kerema  -7.9631  145.7785     76.01        87         100
# 1    Yerbogachen  61.2767  108.0108     26.69        92         100
# 2         Palana  59.1167  159.9667     11.37        88          98
# 3  Mar Del Plata -38.0023  -57.5575     60.87        70          40
# 4           Hilo  19.7297 -155.0900     78.12        78         100
# 5  West Wendover  40.7391 -114.0733     49.21        40           0
# 6         Narsaq  60.9167  -46.0500     38.41        77         100
# 7   Puerto Ayora  -0.7393  -90.3518     80.56        75          98
# 8        Ushuaia -54.8000  -68.3000     51.46        58          40
# 9         Manono  -7.3000   27.4167     67.89        91          96
#
#    Wind Speed Country                 Date
# 0        7.83      PG  2022-03-31 18:52:09
# 1       11.95      RU  2022-03-31 18:52:10
# 2        7.67      RU  2022-03-31 18:52:11
# 3        8.99      AR  2022-03-31 18:52:11
# 4        3.00      US  2022-03-31 18:52:11
# 5       13.80      US  2022-03-31 18:52:12
# 6        1.68      GL  2022-03-31 18:52:13
# 7        5.28      EC  2022-03-31 18:52:13
# 8       11.50      AR  2022-03-31 18:49:38
# 9        4.65      CD  2022-03-31 18:52:14

# %%
# Rearrange columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0         Kerema      PG  2022-03-31 18:52:09  -7.9631  145.7785     76.01
# 1    Yerbogachen      RU  2022-03-31 18:52:10  61.2767  108.0108     26.69
# 2         Palana      RU  2022-03-31 18:52:11  59.1167  159.9667     11.37
# 3  Mar Del Plata      AR  2022-03-31 18:52:11 -38.0023  -57.5575     60.87
# 4           Hilo      US  2022-03-31 18:52:11  19.7297 -155.0900     78.12
# 5  West Wendover      US  2022-03-31 18:52:12  40.7391 -114.0733     49.21
# 6         Narsaq      GL  2022-03-31 18:52:13  60.9167  -46.0500     38.41
# 7   Puerto Ayora      EC  2022-03-31 18:52:13  -0.7393  -90.3518     80.56
# 8        Ushuaia      AR  2022-03-31 18:49:38 -54.8000  -68.3000     51.46
# 9         Manono      CD  2022-03-31 18:52:14  -7.3000   27.4167     67.89
#
#    Humidity  Cloudiness  Wind Speed
# 0        87         100        7.83
# 1        92         100       11.95
# 2        88          98        7.67
# 3        70          40        8.99
# 4        78         100        3.00
# 5        40           0       13.80
# 6        77         100        1.68
# 7        75          98        5.28
# 8        58          40       11.50
# 9        91          96        4.65

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
